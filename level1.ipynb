# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://mroh1226.tistory.com/')
html = response.text
soup = BeautifulSoup(html, 'lxml')

titles = soup.select("strong.tit_post")
for t in titles:
    print(t.get_text(strip=True))
    
cates = soup.select_one(".wrap_sub").attrs
print(cates)
print(cates['id'])
# Out:
# 2. [크롤링] 내 블로그 크롤링 해보기
# 1. [크롤링] 시작
# 서버 트러블 슈팅 게임?
# MCP 해보자
# 17. [ASP .NET Core] EasyNetQ 보내고, 받고 구현
# 그록이 스스로를 백엔드 5년차 라고 하면서 만들어준 답변
# 21. [MS-SQL] Tvp(Table Value Parameter) 활용
# 16. [ASP .NET Core] EasyNetQ 로 RabbitMQ 간편하게 사용하기
# 15. [ASP .NET Core] 확장 메서드에 대한 이해 (Extensions)
# 14. [ASP .NET Core] Connection 비용과 using
# {'id': 'mFeature', 'class': ['wrap_sub']}
# mFeature
